# %%
import pandas as pd

df_clientes = pd.read_csv('CadastroClientes.csv', sep=';')
df_funcionarios = pd.read_csv('CadastroFuncionarios.csv', sep=';', decimal=',')
df_servicos = pd.read_excel(r'BaseServiçosPrestados.xlsx')

display(df_funcionarios)
display(df_clientes)
display(df_servicos)
# Out:
#      ID Funcionário Estado Civil           Nome Completo  Salario Base  \
# 0                 1            C        Gabriel Mesquita         21910
# 1                 2            C             João Haddad          5404
# 2                 3            C  Amanda Marques Ribeiro         16066
# 3                 4            C         Guilherme Nunez         21305
# 4                 5            C           Adelino Gomes          5098
# ..              ...          ...                     ...           ...
# 109             143            C   Renan Scharnhorst Ott         10793
# 110             144            S      Lucas Brum Pereira          4048
# 111             148            S            Caio Stellet         24596
# 112             149            C          Fernanda Rocha          5078
# 113             150            C            Eduardo Brum         15939
#
#      Impostos  Beneficios   VT      VR       Cargo            Area
# ...

# %% [markdown]
# ## ParserError: Error tokenizing data. C error: Expected 2 fields in line 3, saw 3
#
# ### * resolucao
# * usar uma vírgula como separador e oo decimal=',' pra ele identificar que as virgulas dos numeros sao pra indicar decimais, e nao colunas.
# * os numeros com virgula dificultam a leitura do read_csv (pq ele le as virgulas pra separar colunas)
# * ele fica confuso aí da erro

# %% [markdown]
# ## limpeza dos dados

# %%
df_servicos.info()
df_clientes.info()
df_funcionarios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237 entries, 0 to 236
# Data columns (total 4 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Codigo do Servico                237 non-null    object
#  1   ID Funcionário                   237 non-null    int64
#  2   ID Cliente                       237 non-null    int64
#  3   Tempo Total de Contrato (Meses)  237 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 7.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 320 entries, 0 to 319
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID Cliente             320 non-null    int64
#  1   Cliente                320 non-null    object
#  2   Valor Contrato Mensal  320 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 7.6+ KB
# ...

# %%
df_clientes.describe()
df_funcionarios.describe()
df_servicos.describe()
# Out:
#        ID Funcionário  ID Cliente  Tempo Total de Contrato (Meses)
# count      237.000000  237.000000                       237.000000
# mean        69.776371  160.485232                         9.654008
# std         41.148715   94.354614                         2.985579
# min          1.000000    1.000000                         4.000000
# 25%         36.000000   80.000000                         8.000000
# 50%         68.000000  161.000000                        10.000000
# 75%        103.000000  241.000000                        12.000000
# max        150.000000  320.000000                        14.000000

# %%
type(df_clientes['Cliente'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Folha Salarial

# %%
# display(df_funcionarios)
salario_total = df_funcionarios['Salario Base'].sum()
print(f'O valor total gasto com funcionarios da empresa foi R${float(salario_total)}')
# Out:
# O valor total gasto com funcionarios da empresa foi R$1537849.0

# %% [markdown]
# ## Faturamento

# %%
display(df_servicos)
display(df_clientes)

df_faturamento_mensal = df_servicos['Tempo Total de Contrato (Meses)'].merge(df_clientes['Valor Contrato Mensal'])
# Out:
#     Codigo do Servico  ID Funcionário  ID Cliente  \
# 0              OS0001              67           1
# 1              OS0002              17           2
# 2              OS0003             116           4
# 3              OS0004              37           5
# 4              OS0005             130           6
# ..                ...             ...         ...
# 232            OS0233             111         315
# 233            OS0234             124         316
# 234            OS0235              72         317
# 235            OS0236              90         319
# 236            OS0237              22         320
#
#      Tempo Total de Contrato (Meses)
# 0                                 14
# 1                                 12
# 2                                 14
# 3                                  8
# 4                                  8
# ..                               ...
# 232                                4
# 233                                8
# ...
